# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AnhGiaoThong
# Out:
# /content/drive/MyDrive/AnhGiaoThong

# %%
# !unzip -q /content/drive/MyDrive/AnhGiaoThong/train_data -d /content/drive/MyDrive/ # GIẢI NÉN FILE TRAIN_DATA.ZIP RA THƯ MỤC TÊN TRAIN_DATA Ở DRIVE
# Out:
# replace /content/drive/MyDrive/labels/train/img0.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
pip install yolov5

# %%
pip install wandb

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone yoloV5 
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (CPU)

# %%
# Train data
# Batch càng tăng thì thời gian chạy càng ngắn nhưng ngốn RAM nhiều hơn, ảnh train kích thước 640 x 640 vì dùng model yolov5s (model này thích hợp cho mô hình có dữ liệu nhỏ)
# Tìm ra số epochs tối ưu vì epochs thấp mô hình sẽ bị Underfitting, quá cao sẽ dẫn đến Overfitting 
# !python /content/drive/MyDrive/yolov5/train.py --img 640 --batch 16 --epochs 150 --data /content/drive/MyDrive/yolov5/data/custom.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: vietvuive (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/yolov5/data/custom.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-193-gdb1f83b torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# Chạy đánh giá thuật toán
# !python /content/drive/MyDrive/yolov5/val.py --weights /content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt --data /content/drive/MyDrive/yolov5/data/custom.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=/content/drive/MyDrive/yolov5/data/custom.yaml, weights=['/content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.0-193-gdb1f83b torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7174642 parameters, 0 gradients, 16.3 GFLOPs
# val: Scanning '../train_data/labels/val' images and labels...414 found, 1 missing, 0 empty, 0 corrupted: 100% 415/415 [01:57<00:00,  3.53it/s]
# val: New cache created: ../train_data/labels/val.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 13/13 [03:02<00:00, 14.03s/it]
#                  all        415        565      0.853      0.922      0.921      0.707
# ...

# %%
#Detect hình ảnh
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/yolov5/data/images
# Out:
# ...
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/yolov5/data/images, data=drive/MyDrive/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-193-gdb1f83b torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7174642 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/drive/MyDrive/yolov5/data/images/1.jpg: 448x640 1 CamXeTren10Tan, 1 CamOToKhachVaOToTai, Done. (0.021s)
# Speed: 0.6ms pre-process, 21.0ms inference, 30.5ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
#Chạy code detect ảnh trong video
# !python /content/drive/MyDrive/yolov5/detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/AnhGiaoThong/A
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/AnhGiaoThong/A, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-193-gdb1f83b torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7174642 parameters, 0 gradients, 16.3 GFLOPs
# video 1/1 (1/905) /content/drive/MyDrive/AnhGiaoThong/A/10.mov: 384x640 Done. (0.017s)
# video 1/1 (2/905) /content/drive/MyDrive/AnhGiaoThong/A/10.mov: 384x640 Done. (0.015s)
# video 1/1 (3/905) /content/drive/MyDrive/AnhGiaoThong/A/10.mov: 384x640 Done. (0.016s)
# ...
